# %%
print("hello")
# Out:
# hello

# %%
type[5]
# Out:
# type[5]

# %%
#type(5)
type(5)
# Out:
# int

# %%
type(2.1)
# Out:
# float

# %%
a = 7
a = a + 1
print(a)
# Out:
# 8

# %%
a = 7
a += 1
print(a)
# Out:
# 8

# %%
b = 5
b = b * 2
print(b)
# Out:
# 10

# %%
b= 5
b *= 2
print(b)
# Out:
# 10

# %%
# 큰 따옴표
"AIFFEL", type("AIFFEL")
# Out:
# ('AIFFEL', str)

# %%
'환영합니다!', type('환영합니다!')
# Out:
# ('환영합니다!', str)

# %%
"""끝까지 열심히""", type("""끝까지 열심히""")
# Out:
# ('끝까지 열심히', str)

# %%
'''파이썬 공부해요!''', type('''파이썬 공부해요!''')
# Out:
# ('파이썬 공부해요!', str)

# %%
'''"파이썬 공부해요!"''', type('''파이썬 공부해요!''')
# Out:
# ('"파이썬 공부해요!"', str)

# %%
'''"파이썬 공부해요!"''', type('''파이썬 공부해요!''')
# Out:
# ('"파이썬 공부해요!"', str)

# %%
python = """파이썬이 
이렇게
재밌다니!"""

print(python)
# Out:
# 파이썬이
# 이렇게
# 재밌다니!

# %%
# 문자열이 여러 줄인 경우(큰 따옴표 연속 3개)
python = """파이썬이 
이렇게
재밌다니!"""

print(python)
# Out:
# 파이썬이
# 이렇게
# 재밌다니!

# %%
# 문자열에 따옴표를 포함시키고 싶을 때 
lucky = "'AIFFEL'을 선택한 여러분 모두 lucky!"
print(lucky)
# Out:
# 'AIFFEL'을 선택한 여러분 모두 lucky!

# %%
# 문자열에 따옴표를 포함시키고 싶을 때 
lucky = "'AIFFEL'을 선택한 여러분 모두 lucky!"
print(lucky)
# Out:
# 'AIFFEL'을 선택한 여러분 모두 lucky!

# %%
# [Playground] 문자열을 만드는 4가지 방법을 연습해 보세요. 결과는 하나만 나오니 각 방법을 하나씩 연습해 보세요!  
# 큰 따옴표(")로 둘러싸기
# [[YOUR CODE]]
# 작은 따옴표(')로 둘러싸기
# [[YOUR CODE]]
# 큰 따옴표 연속 3개(""")로 둘러싸기
# [[YOUR CODE]]
# 작은 따옴표 연속 3개(''')로 둘러싸기
# [[YOUR CODE]]

# %%
# `\t` 예시
tabline = 'hello\tpython'
print(tabline)
# Out:
# hello	python

# %%
# `\n` 예시  
# 고전 시가의 행 사이에 \n 추가
hwang = '동짓달 기나긴 밤을 한 허리를 베어내어 \n봄바람 이불 아래 서리서리 넣었다가 \n정든 임 오신 날 밤이거든 굽이굽이 펴리라'

print(hwang)
# Out:
# 동짓달 기나긴 밤을 한 허리를 베어내어
# 봄바람 이불 아래 서리서리 넣었다가
# 정든 임 오신 날 밤이거든 굽이굽이 펴리라

# %%
num = \
13*1 +\
13*2 +\
13*3 +\
13*4

print(num)
# Out:
# 130
